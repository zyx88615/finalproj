# %%
# import dependencies
gkey = "AIzaSyC0STDUKInUkvPhNIz9AbNQNdvDLW5Ys3k"

#ying AIzaSyBMGtHDYsNWe763paBu7QKXTs62dqXOL5k
#pam AIzaSyC0STDUKInUkvPhNIz9AbNQNdvDLW5Ys3k
#neal AIzaSyCzxJM61ktvKKlvX0HwZbzsXcCmYY2CqVU

#ting AIzaSyCpVdVbZlrPPVIIacGHegfKjAaYVV2EndQ
#nick AIzaSyBdniv4ah4kYr7VcWZuU_689Bw8p2-eQWE

import requests 
import json

from pprint import pprint
import pandas as pd

# %%
# read movie list 
file = "../Data/movie_lists/movies_2015.csv"
movies_df = pd.read_csv(file)
movies_df.head()
# Out:
#    Number Release Date                                       Movie  \
# 0      34   2015-12-31                        Julija in alfa Romeo
# 1      64   2015-12-31  Chiamatemi Francesco - Il papa della gente
# 2      58   2015-12-31                                San cheng ji
# 3       5   2015-12-31                                  Sardaar Ji
# 4      75   2015-12-31                            Walking to Paris
#
#    Production Budget  Domestic Gross  Worldwide Gross
# 0           560000.0             0.0           8462.0
# 1         15000000.0             0.0        3925769.0
# 2         12000000.0             0.0        1950194.0
# 3          2700000.0             0.0        8200000.0
# 4           300000.0             0.0              0.0

# %%
# create list from movie column
movies = movies_df['Movie'].tolist()
len(movies)
# Out:
# 338

# %%
# add Official Trailer for youtube search 
movies_trailer = [m + " Official Trailer" for m in movies]

# %%
# need to separate movie list into 20 to keep youtube requests small
split = [movies_trailer[x:x+20] for x in range(0, len(movies_trailer), 20)]
split
# Out:
# [['Julija in alfa Romeo Official Trailer',
#   'Chiamatemi Francesco - Il papa della gente Official Trailer',
#   'San cheng ji Official Trailer',
#   'Sardaar Ji Official Trailer',
#   'Walking to Paris Official Trailer',
#   'To Be Frank, Sinatra at 100 Official Trailer',
#   'Wind Walkers Official Trailer',
#   "Pourquoi j'ai pas mang mon pre Official Trailer",
#   'Unnatural Official Trailer',
#   'Vaalu Official Trailer',
#   'Escaping the Holocost Official Trailer',
#   'The Veil Official Trailer',
#   'Lumea e a mea Official Trailer',
#   'Romantic Schemer Official Trailer',
#   'Rodeo Girl Official Trailer',
#   'Lunchtime Heroes Official Trailer',
#   'Henry Joseph Church Official Trailer',
#   'Fight to the Finish Official Trailer',
#   'Aztec Warrior Official Trailer',
#   'Geroy Official Trailer'],
#  ['AWOL-72 Official Trailer',
#   'Shooting the Warwicks Official Trailer',
#   'Karachi se Lahore Official Trailer',
#   'Anomalisa Official Trailer',
#   'Concussion Official Trailer',
#   'The Revenant Official Trailer',
#   'The Hateful Eight Official Trailer',
#   'Joy Official Trailer',
#   'Daddys Home Official Trailer',
#   'Point Break Official Trailer',
#   'Por amor en el caserio Official Trailer',
#   'Star Wars Ep. VII: The Force Awakens Official Trailer',
#   'Alvin and the Chipmunks: The Road Chip Official Trailer',
#   'Sisters Official Trailer',
#   'Saul fia Official Trailer',
#   'In the Heart of the Sea Official Trailer',
#   'The Big Short Official Trailer',
#   'O Menino e o Mundo Official Trailer',
#   'American Hero Official Trailer',
#   'Close Range Official Trailer'],
#  ['The Ridiculous 6 Official Trailer',
#   'Outside Bet Official Trailer',
#   'The DUFF Official Trailer',
#   'McFarland, USA Official Trailer',
#   'Hot Tub Time Machine 2 Official Trailer',
#   'Girlhouse Official Trailer'],
#  ['Kingsman: The Secret Service Official Trailer',
#   'Hits Official Trailer',
#   'Fifty Shades of Grey Official Trailer',
#   'The Last Five Years Official Trailer',
#   'Love in the Time of Monsters Official Trailer',
#   'Fear Clinic Official Trailer',
#   'Jupiter Ascending Official Trailer',
#   'Enter the Dangerous Mind Official Trailer',
#   'The SpongeBob Movie: Sponge Out of Water Official Trailer',
#   'Seventh Son Official Trailer',
#   'UnDivided Official Trailer',
#   'Bleeding Hearts Official Trailer',
#   'Trudno byt bogom Official Trailer',
#   'Above and Beyond Official Trailer',
#   'Black or White Official Trailer',
#   'Guten Tag, Ramon Official Trailer',
#   'Wild Card Official Trailer',
#   'Project Almanac Official Trailer',
#   'Born of War Official Trailer',
#   'Song One Official Trailer'],
#  ['Mortdecai Official Trailer',
#   'Mommy Official Trailer',
#   'R100 Official Trailer',
#   'The Boy Next Door Official Trailer',
#   'Veronika Decides to Die Official Trailer',
#   'The Opposite Sex Official Trailer',
#   'Blackhat Official Trailer',
#   'Paddington Official Trailer',
#   'The Wedding Ringer Official Trailer',
#   'Still Alice Official Trailer',
#   'Capricorn One Official Trailer',
#   'Da Sweet Blood of Jesus Official Trailer',
#   'Black November Official Trailer',
#   "Let's Kill Ward's Wife Official Trailer",
#   'Vessel Official Trailer',
#   'Taken 3 Official Trailer',
#   'Selma Official Trailer',
#   '4/11 Official Trailer']]

# %%
# 11 lists from total 220, each 20 
m1 = split[0]
m2 = split[1]
m3 = split[2]
m4 = split[3]
m5 = split[4]
m6 = split[5]
m7 = split[6]
m8 = split[7]
m9 = split[8]
m10 = split[9]
m11 = split[10]

print(m11)
# Out:
# ['Freedom Official Trailer', 'Insidious Chapter 3 Official Trailer', 'Testament of Youth Official Trailer', 'Dawn Patrol Official Trailer', 'Spy! Official Trailer', 'United Passions Official Trailer', 'Entourage Official Trailer', 'San Andreas Official Trailer', 'Aloha Official Trailer', 'Survivor Official Trailer', 'Mutant World Official Trailer', 'Aloft Official Trailer', 'Poltergeist Official Trailer', 'Drunk Wedding Official Trailer', 'Tomorrowland Official Trailer', 'Into the Grizzly Maze Official Trailer', 'Family Motocross Official Trailer', 'Pound of Flesh Official Trailer', 'Pitch Perfect 2 Official Trailer', 'Mad Max: Fury Road Official Trailer']

# %%
base_url = "https://www.googleapis.com/youtube/v3/"

# %% [markdown]
# ## 1st request

# %%
# new dictionary
d = {}

# try to retrieve videoID for movies in m1 first 
for movie in m1: 
    search_url = base_url + ("search?part=snippet&maxResults=1&q={0}&key={1}").format(movie, gkey)
    
    response = requests.get(search_url).json()
    # check response
    pprint(response)
    
    # add to key-value pair of movie and videoID to dictionary
    d[movie] = response["items"][0]["id"]["videoId"]

pprint(d)
# Out:
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/7Twq9QY3U2tW2MVexVmw12W9Ai8"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/UKGAQvH8AuMjLI_zXRkfqBwYJFo"',
#             'id': {'kind': 'youtube#video', 'videoId': 'nWAlqiaHr7s'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC9V8-OeDoJfkiHw6I85wgpg',
#                         'channelTitle': 'Perfo Produkcija',
#                         'description': 'Juliet and alfa Romeo - Official Int. '
#                                        'Trailer, film directed by Blaž '
#                                        'Završnik.',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-07-20T13:36:13.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/nWAlqiaHr7s/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/nWAlqiaHr7s/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/nWAlqiaHr7s/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'JULIET AND ALFA ROMEO - Official '
#                                  'International Trailer (2015)'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 275},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/IjWybwZ673DeTf14CrZOQ7r42QU"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/7Qs9I6OZY6L-2QdwxzkHU-9__lw"',
#             'id': {'kind': 'youtube#video', 'videoId': '3YfRqql_cfk'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCGCbxpnt25hWPFLSbvwfg_w',
#                         'channelTitle': 'FilmIsNow Trailer & Clip in Italiano',
#                         'description': 'Iscriviti al nostro canale: '
#                                        'http://bit.ly/GFunSg Guarda il trailer '
#                                        'italiano ufficiale di CHIAMATEMI '
#                                        'FRANCESCO. Un biografico diretto da '
#                                        'Daniele Luchetti - dal 3 ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-11-23T10:39:10.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/3YfRqql_cfk/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/3YfRqql_cfk/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/3YfRqql_cfk/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Chiamatemi Francesco Trailer Italiano (2015) '
#                                  'HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 469},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/NXf4xCXuJ1hR05vkV_P1JygR-h0"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/UFuqMTm63k_kXVaM5EWhRtGDmG0"',
#             'id': {'kind': 'youtube#video', 'videoId': 'C0Vv2tPk6-0'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UClQMqeJEqhdvtsI9-Dol1UQ',
#                         'channelTitle': 'susunuz',
#                         'description': 'http://www.susunuz.com/turkce-dublaj-filmler/uc-sehrin-hikayesi/izle.html '
#                                        '2. Dünya Savaşı içerisinde geçen '
#                                        'romantik anıları ele alan hikayenin '
#                                        'asıl kahramanları ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2016-12-26T09:37:12.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/C0Vv2tPk6-0/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/C0Vv2tPk6-0/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/C0Vv2tPk6-0/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Üç Şehrin Hikayesi ( San cheng ji ) - '
#                                  'FRAGMAN (susunuz.com)'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 39254},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/6utywlhJ9OLjbLrbrwnFgnfxsBI"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/cFhxr4q2RkKIVywmpohiifggnII"',
#             'id': {'kind': 'youtube#video', 'videoId': 'MuMcSiIqCpc'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCopY0NAzASqmD6eVaRj2TFQ',
#                         'channelTitle': 'White Hill Music',
#                         'description': 'White Hill Productions Presents '
#                                        '"SARDAARJI" In Association with '
#                                        'Dalmora Entertainment A Film by Rohit '
#                                        'Jugraj Starring : Diljit Dosanjh, '
#                                        'Neeru Bajwa, Mandy ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-05-18T14:00:34.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/MuMcSiIqCpc/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/MuMcSiIqCpc/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/MuMcSiIqCpc/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Sardaar ji | Official Trailer | Diljit '
#                                  'Dosanjh, Neeru Bajwa, Mandy Takhar | '
#                                  'Releasing 26th June'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/-F6LHBkJmQ8MduGcUQ0ns-glqtE"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/feoTeRFlofHILFB5n7RC4JALRVc"',
#             'id': {'kind': 'youtube#playlist',
#                    'playlistId': 'PL0acm0TC31hjuV-5n32KZodAxhw1P4RsA'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCZvUoz3nXqVyHpKQGafzCKQ',
#                         'channelTitle': 'sumarpachu',
#                         'description': 'See this : '
#                                        ':http://tinyurl.com/y8axz4ro Walking '
#                                        'to Paris F.u.l.l M.o.v.i.e 2019, '
#                                        'Walking to Paris F.u.l.l M.o.v.i.e, '
#                                        'Walking to Paris (2019) f.u.l.l '
#                                        'm.o.v.i.e, Walking to ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2018-10-14T14:30:12.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/Dq3_fgLOoHc/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/Dq3_fgLOoHc/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/Dq3_fgLOoHc/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Walking to Paris FULL Movie[2019]'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-ac09c5e0c690> in <module>
#      11
#      12     # add to key-value pair of movie and videoID to dictionary
# ---> 13     d[movie] = response["items"][0]["id"]["videoId"]
#      14
#      15 pprint(d)
#
# KeyError: 'videoId'

# %%
# create dataframe from dictionary
df = pd.DataFrame.from_dict(list(d.items()))
df = df.rename(columns={0: "movie_trailer", 1: "video_id"})
df
# Out:
#                                        movie_trailer     video_id
# 0              Julija in alfa Romeo Official Trailer  nWAlqiaHr7s
# 1  Chiamatemi Francesco - Il papa della gente Off...  3YfRqql_cfk
# 2                      San cheng ji Official Trailer  C0Vv2tPk6-0
# 3                        Sardaar Ji Official Trailer  MuMcSiIqCpc

# %%
df["video_title"] = ""
df["channel_name"] = ""
df["channel_id"] = ""
df["comment_count"] = ""
df["view_count"] = ""
df["like_count"] = ""
df["date_published"] = ""

# for loop to retrieve view count, comment count, like count for each video
for index, row in df.iterrows():
    video = row["video_id"]
    index = index
    
    final_url = base_url + ("videos?part=snippet%2C+statistics&id={0}&key={1}").format(video, gkey)
    final_results = requests.get(final_url).json()
    vid_response = final_results["items"]
    
    for i in vid_response:
        t = i.get("snippet").get("title")
        c = i.get("snippet").get("channelTitle")
        d = i.get("snippet").get("channelId")
        m = i.get("snippet").get("publishedAt")

        comment_count = i.get("statistics").get("commentCount")
        view_count = i.get("statistics").get("viewCount")
        like_count = i.get("statistics").get("likeCount")
      
        df.loc[index, "video_title"] = t
        df.loc[index, "channel_name"] = c
        df.loc[index, "channel_id"] = d
        df.loc[index, "comment_count"] = comment_count
        df.loc[index, "view_count"] = view_count
        df.loc[index, "like_count"] = like_count
        df.loc[index, "date_published"] = m
df
# Out:
#                                        movie_trailer     video_id  \
# 0              Julija in alfa Romeo Official Trailer  nWAlqiaHr7s
# 1  Chiamatemi Francesco - Il papa della gente Off...  3YfRqql_cfk
# 2                      San cheng ji Official Trailer  C0Vv2tPk6-0
# 3                        Sardaar Ji Official Trailer  MuMcSiIqCpc
#
#                                          video_title  \
# 0  JULIET AND ALFA ROMEO - Official International...
# 1    Chiamatemi Francesco Trailer Italiano (2015) HD
# 2  Üç Şehrin Hikayesi ( San cheng ji ) - FRAGMAN ...
# 3  Sardaar ji | Official Trailer | Diljit Dosanjh...
#
#                            channel_name                channel_id  \
# 0                      Perfo Produkcija  UC9V8-OeDoJfkiHw6I85wgpg
# 1  FilmIsNow Trailer & Clip in Italiano  UCGCbxpnt25hWPFLSbvwfg_w
# 2                               susunuz  UClQMqeJEqhdvtsI9-Dol1UQ
# 3                      White Hill Music  UCopY0NAzASqmD6eVaRj2TFQ
#
#   comment_count view_count like_count            date_published
# 0             1      18901         36  2015-07-20T13:36:13.000Z
# 1            19      79487        288  2015-11-23T10:39:10.000Z
# 2             0        283          0  2016-12-26T09:37:12.000Z
# 3           569    2955866      13077  2015-05-18T14:00:34.000Z

# %% [markdown]
# ## 2nd request

# %%
# new dictionary
d2 = {}

# try to retrieve videoID for movies in m1 first 
for movie in m2: 
    search_url = base_url + ("search?part=snippet&maxResults=1&q={0}&key={1}").format(movie, gkey)
    
    response = requests.get(search_url).json()
    # check response
    pprint(response)
    
    # add to key-value pair of movie and videoID to dictionary
    d2[movie] = response["items"][0]["id"]["videoId"]

# create another (same) for loop for m2, m3..etc 
pprint(d2)
# Out:
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/dnRqmcDBssJ4E0vGXbgODtxygDo"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/O6i6kmjzrO-PhlD3E5DMN4aWpWA"',
#             'id': {'kind': 'youtube#video', 'videoId': 'hDeicO2ntD8'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCLyYEq4ODlw3OD9qhGqwimw',
#                         'channelTitle': 'Movieclips Indie',
#                         'description': 'Subscribe to INDIE & FILM FESTIVALS: '
#                                        'http://bit.ly/1wbkfYg Subscribe to '
#                                        'TRAILERS: http://bit.ly/sxaw6h '
#                                        'Subscribe to COMING SOON: '
#                                        'http://bit.ly/H2vZUn Like ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-09-04T19:37:28.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/hDeicO2ntD8/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/hDeicO2ntD8/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/hDeicO2ntD8/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'AWOL-72 Official Trailer 1 (2015) - RZA '
#                                  'Thriller HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 13802},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/PT-P_4Lphlt6ljiuFdUMFXNE8Ek"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/9BI28tp01pyzey8XcIfHxgXB6O8"',
#             'id': {'kind': 'youtube#video', 'videoId': '7Rsl6hTIaGs'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCOoGC9T02cOgxIaClgh6C7w',
#                         'channelTitle': 'Vega Baby',
#                         'description': 'Amazon Prime Video: '
#                                        'https://www.amazon.com/Shooting-Warwicks-Adam-Rifkin/dp/B07LGBN8BF/ref=tmm_aiv_swatch_1?',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-07-10T21:54:00.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/7Rsl6hTIaGs/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/7Rsl6hTIaGs/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/7Rsl6hTIaGs/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'SHOOTING THE WARWICKS Trailer - Comedy '
#                                  'Movie'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 123461},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/PPTuvQjLGAKNzM3TIKLwkLwm1og"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/C2FOULu8qgPiyks32LjTVnBPEr0"',
#             'id': {'kind': 'youtube#video', 'videoId': 'WkHsPQjGxNw'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCkvPHvcNlWzHEu_z5RKAeEA',
#                         'channelTitle': 'AryMiP',
#                         'description': 'Karachi Se Lahore is a 2015 Pakistani '
#                                        'comedy road film directed and produced '
#                                        'by Wajahat Rauf. This is the first '
#                                        'Pakistani road-trip film, which covers '
#                                        'the 36 ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2017-04-21T13:46:00.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/WkHsPQjGxNw/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/WkHsPQjGxNw/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/WkHsPQjGxNw/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Karachi Se Lahore 2015 | Trailer'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 926376},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/F8xRE2SjSB5gIeHawNQcMheO6BU"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/VIxlcm8rO6YacGEEWOcM_xO8LGA"',
#             'id': {'kind': 'youtube#video', 'videoId': 'WQkHA3fHk_0'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCF9imwPMSGz4Vq1NiTWCC7g',
#                         'channelTitle': 'Paramount Pictures',
#                         'description': 'From writer Charlie Kaufman (Being '
#                                        'John Malkovich, Eternal Sunshine of '
#                                        'the Spotless Mind) and Duke Johnson '
#                                        '(Moral Orel, Frankenhole) comes '
#                                        'Anomalisa.',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-11-03T17:31:37.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/WQkHA3fHk_0/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/WQkHA3fHk_0/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/WQkHA3fHk_0/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'ANOMALISA - Trailer (2015) - Paramount '
#                                  'Pictures'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 31591},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/G3GS0s4DC7wZvqi7Zk3PPfLf_RA"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/_vNvL2fR0XP_N3_aAMOMOFrvdEU"',
#             'id': {'kind': 'youtube#video', 'videoId': 'Io6hPdC41RM'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCz97F7dMxBNOfGYu3rx8aCw',
#                         'channelTitle': 'Sony Pictures Entertainment',
#                         'description': 'Tell the truth. This December watch '
#                                        'Will Smith transform into Dr. Bennet '
#                                        'Omalu. Join the discussion at '
#                                        'www.concussion-movie.com #ForTheGame '
#                                        '...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-08-31T16:00:00.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/Io6hPdC41RM/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/Io6hPdC41RM/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/Io6hPdC41RM/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'CONCUSSION - Official Trailer (HD)'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/mSqqYDEkKpKFZo-1ZE9rB_ByEpg"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/a6e9A3MSbzFgcye48Yx_eYPNOQ0"',
#             'id': {'kind': 'youtube#video', 'videoId': 'LoebZZ8K5N0'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC2-BeLxzUBSs0uSrmzWhJuQ',
#                         'channelTitle': '20th Century Fox',
#                         'description': 'When all is lost, you fight. Watch the '
#                                        'new trailer for The Revenant Movie, in '
#                                        'theaters this December. Inspired by '
#                                        'true events, THE REVENANT is an '
#                                        'immersive ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-09
'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCZGYJFUizSax-yElQaFDp5Q',
#                         'channelTitle': 'Star Wars',
#                         'description': 'Watch the official trailer for Star '
#                                        'Wars: The Force Awakens, coming to '
#                                        'theaters December 18, 2015. Visit Star '
#                                        'Wars at http://www.starwars.com '
#                                        'Subscribe to Star ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-10-20T02:08:38.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/sGbxmsDFVnE/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/sGbxmsDFVnE/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/sGbxmsDFVnE/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Star Wars: The Force Awakens Trailer '
#                                  '(Official)'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/hqhbNTAh_r05DSCv_2Lge5DrKOw"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/8tGlKd0Xp1kxqYnKz3W6OBnerqE"',
#             'id': {'kind': 'youtube#video', 'videoId': 'xA6cOSEZhzM'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCi8e0iOVk1fEOogdfu4YgfA',
#                         'channelTitle': 'Movieclips Trailers',
#                         'description': 'Subscribe to TRAILERS: '
#                                        'http://bit.ly/sxaw6h Subscribe to '
#                                        'COMING SOON: http://bit.ly/H2vZUn Like '
#                                        'us on FACEBOOK: http://bit.ly/1QyRMsE '
#                                        'Follow us on ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-10-29T16:08:11.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/xA6cOSEZhzM/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/xA6cOSEZhzM/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/xA6cOSEZhzM/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Alvin and the Chipmunks: The Road Chip '
#                                  'Official Trailer #1 (2015) - Animated Movie '
#                                  'HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 291779},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/cHJFp-RUqv5XS3DCIcqgdTMBaag"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/GqLxFLDl4K-wY_ZmuaRWGMcJzKM"',
#             'id': {'kind': 'youtube#video', 'videoId': 'vRnhEjP3R-c'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCq0OueAsdxH6b8nyAspwViw',
#                         'channelTitle': 'Universal Pictures',
#                         'description': 'Sisters - Official Trailer (HD) In '
#                                        'Theaters December 18, 2015. '
#                                        'http://www.sistersfilm.com / '
#                                        '#SistersMovie Tina Fey and Amy Poehler '
#                                        'reunite for Sisters, a new film ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-07-15T04:35:41.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/vRnhEjP3R-c/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/vRnhEjP3R-c/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/vRnhEjP3R-c/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Sisters - Official Trailer (HD)'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/eYGBsM5bcl34ZRzaoWD6sXbdc9A"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/QmpZw0YsjtT8YYM7i9kB7fU68QY"',
#             'id': {'kind': 'youtube#video', 'videoId': '3wMzPztPavs'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCLyYEq4ODlw3OD9qhGqwimw',
#                         'channelTitle': 'Movieclips Indie',
#                         'description': 'Subscribe to INDIE & FILM FESTIVALS: '
#                                        'http://bit.ly/1wbkfYg Subscribe to '
#                                        'TRAILERS: http://bit.ly/sxaw6h '
#                                        'Subscribe to COMING SOON: '
#                                        'http://bit.ly/H2vZUn Like ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-11-18T20:55:51.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/3wMzPztPavs/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/3wMzPztPavs/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/3wMzPztPavs/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Son of Saul Trailer 1 (2015) - Geza Rohrig '
#                                  'Holocaust Drama Movie HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 4699},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/D3FXSmq4V_NjmasU8qvPzLazU8I"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/y31b2htG07Oqwm0ZAp9hHz1CuYg"',
#             'id': {'kind': 'youtube#video', 'videoId': 'K-H35Mpj4uk'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCjmJDM5pRKbUlVIzDYYWb6g',
#                         'channelTitle': 'Warner Bros. Pictures',
#                         'description': "Chris Hemsworth stars in Ron Howard's "
#                                        'IN THE HEART OF THE SEA, in theaters '
#                                        'December 2015. '
#                                        'http://intheheartoftheseamovie.com ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-11-02T01:15:32.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/K-H35Mpj4uk/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/K-H35Mpj4uk/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/K-H35Mpj4uk/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'In the Heart of the Sea - Final Trailer '
#                                  '[HD]'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/2wEfwLwH2do7KqqxuVUfO1fE0mI"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/SlAdoGcyKPqQwnUvl-J0Dz6sC6k"',
#             'id': {'kind': 'youtube#video', 'videoId': 'vgqG3ITMv1Q'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'U
#  'Star Wars Ep. VII: The Force Awakens Official Trailer': 'sGbxmsDFVnE',
#  'The Big Short Official Trailer': 'vgqG3ITMv1Q',
#  'The Hateful Eight Official Trailer': 'nIOmotayDMY',
#  'The Revenant Official Trailer': 'LoebZZ8K5N0'}

# %%
# create dataframe from dictionary
df2 = pd.DataFrame.from_dict(list(d2.items()))
df2 = df2.rename(columns={0: "movie_trailer", 1: "video_id"})
df2
# Out:
#                                         movie_trailer     video_id
# 0                            AWOL-72 Official Trailer  hDeicO2ntD8
# 1              Shooting the Warwicks Official Trailer  7Rsl6hTIaGs
# 2                  Karachi se Lahore Official Trailer  WkHsPQjGxNw
# 3                          Anomalisa Official Trailer  WQkHA3fHk_0
# 4                         Concussion Official Trailer  Io6hPdC41RM
# 5                       The Revenant Official Trailer  LoebZZ8K5N0
# 6                  The Hateful Eight Official Trailer  nIOmotayDMY
# 7                                Joy Official Trailer  uR-2TiQVY-k
# 8                        Daddys Home Official Trailer  2sgpwTBnuLo
# 9                        Point Break Official Trailer  ncvFAm4kYCo
# 10            Por amor en el caserio Official Trailer  BcM47Xo_tt4
# 11  Star Wars Ep. VII: The Force Awakens Official ...  sGbxmsDFVnE
# 12  Alvin and the Chipmunks: The Road Chip Officia...  xA6cOSEZhzM
# 13                           Sisters Official Trailer  vRnhEjP3R-c
# 14                          Saul fia Official Trailer  3wMzPztPavs
# 15           In the Heart of the Sea Official Trailer  K-H35Mpj4uk
# 16                     The Big Short Official Trailer  vgqG3ITMv1Q
# 17                O Menino e o Mundo Official Trailer  l7x8oi_1GBo
# 18                     American Hero Official Trailer  StDQ_P99rPo
# 19                       Close Range Official Trailer  GIQWR7qQzvQ

# %%
df2["video_title"] = ""
df2["channel_name"] = ""
df2["channel_id"] = ""
df2["comment_count"] = ""
df2["view_count"] = ""
df2["like_count"] = ""
df2["date_published"] = ""

# for loop to retrieve view count, comment count, like count for each video
for index, row in df2.iterrows():
    video = row["video_id"]
    index = index
    
    final_url = base_url + ("videos?part=snippet%2C+statistics&id={0}&key={1}").format(video, gkey)
    final_results = requests.get(final_url).json()
    vid_response = final_results["items"]
    
    for i in vid_response:
        t = i.get("snippet").get("title")
        c = i.get("snippet").get("channelTitle")
        d = i.get("snippet").get("channelId")
        m = i.get("snippet").get("publishedAt")

        comment_count = i.get("statistics").get("commentCount")
        view_count = i.get("statistics").get("viewCount")
        like_count = i.get("statistics").get("likeCount")
      
        df2.loc[index, "video_title"] = t
        df2.loc[index, "channel_name"] = c
        df2.loc[index, "channel_id"] = d
        df2.loc[index, "comment_count"] = comment_count
        df2.loc[index, "view_count"] = view_count
        df2.loc[index, "like_count"] = like_count
        df2.loc[index, "date_published"] = m
df2
# Out:
#                                         movie_trailer     video_id  \
# 0                            AWOL-72 Official Trailer  hDeicO2ntD8
# 1              Shooting the Warwicks Official Trailer  7Rsl6hTIaGs
# 2                  Karachi se Lahore Official Trailer  WkHsPQjGxNw
# 3                          Anomalisa Official Trailer  WQkHA3fHk_0
# 4                         Concussion Official Trailer  Io6hPdC41RM
# 5                       The Revenant Official Trailer  LoebZZ8K5N0
# 6                  The Hateful Eight Official Trailer  nIOmotayDMY
# 7                                Joy Official Trailer  uR-2TiQVY-k
# 8                        Daddys Home Official Trailer  2sgpwTBnuLo
# 9                        Point Break Official Trailer  ncvFAm4kYCo
# 10            Por amor en el caserio Official Trailer  BcM47Xo_tt4
# 11  Star Wars Ep. VII: The Force Awakens Official ...  sGbxmsDFVnE
# 12  Alvin and the Chipmunks: The Road Chip Officia...  xA6cOSEZhzM
# 13                           Sisters Official Trailer  vRnhEjP3R-c
# 14                          Saul fia Official Trailer  3wMzPztPavs
movieclips Trailers  UCi8e0iOVk1fEOogdfu4YgfA          1439
# 19  FilmIsNow Action Movie Trailers  UCP5Q315vMoQoMWUukmWOGGw           577
#
#    view_count like_count            date_published
# 0      334406        188  2015-09-04T19:37:28.000Z
# 1        8708         13  2015-07-10T21:54:00.000Z
# 2       83430        357  2017-04-21T13:46:00.000Z
# 3     1087448       3266  2015-11-03T17:31:37.000Z
# 4    18179525      23460  2015-08-31T16:00:00.000Z
# 5    23030790      59243  2015-09-29T13:15:09.000Z
# 6     4916035      21017  2015-08-12T16:07:54.000Z
# 7     8622717      20169  2015-10-21T12:59:10.000Z
# 8     6641982      20853  2015-06-19T16:53:05.000Z
# 9    22463874      48182  2015-05-26T23:00:01.000Z
# 10      12235         95  2013-12-03T22:06:30.000Z
# 11  103711452     726155  2015-10-20T02:08:38.000Z
# 12    5516273      18376  2015-10-29T16:08:11.000Z
# 13   12666371      20723  2015-07-15T04:35:41.000Z
# 14     834721       1074  2015-11-18T20:55:51.000Z
# 15   12360327      45883  2015-11-02T01:15:32.000Z
# 16    9276508      20904  2015-09-22T12:44:46.000Z
# 17     207444       2728  2015-06-05T09:33:15.000Z
# 18    7640942      30107  2015-11-07T18:00:00.000Z
# 19    4780261       8129  2015-02-11T15:34:05.000Z

# %%
combined_df = df.append(df2)
combined_df.count()
# Out:
# movie_trailer     24
# video_id          24
# video_title       24
# channel_name      24
# channel_id        24
# comment_count     24
# view_count        24
# like_count        24
# date_published    24
# dtype: int64

# %% [markdown]
# ## 3rd request

# %%
# new dictionary
d3 = {}

# try to retrieve videoID for movies in m1 first 
for movie in m3: 
    search_url = base_url + ("search?part=snippet&maxResults=1&q={0}&key={1}").format(movie, gkey)
    
    response = requests.get(search_url).json()
    # check response
    pprint(response)
    
    # add to key-value pair of movie and videoID to dictionary
    d3[movie] = response["items"][0]["id"]["videoId"]

# create another (same) for loop for m2, m3..etc 
pprint(d3)
# Out:
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/W5N8D_5j2vWV_YsCQzWH-sEuYoI"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/rt3SRsm0S8pahG4xEhnN3yYscFo"',
#             'id': {'kind': 'youtube#video', 'videoId': 'qUp7Qgimn38'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCWOA1ZGywLbqmigxE4Qlvuw',
#                         'channelTitle': 'Netflix',
#                         'description': 'When his long-lost outlaw father '
#                                        'returns, Tommy "White Knife" Stockburn '
#                                        'goes on an adventure-filled journey '
#                                        'across the Old West with his five '
#                                        'brothers.',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-10-27T15:25:07.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/qUp7Qgimn38/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/qUp7Qgimn38/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/qUp7Qgimn38/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'The Ridiculous 6 | Official Trailer [HD] | '
#                                  'Netflix'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/J5ASFu8s3OdrXtcwuXnb1LbtJn8"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/wYGU39ar6MVKRKvPpo719WpGCYI"',
#             'id': {'kind': 'youtube#video', 'videoId': 'KFzbZZCLnjQ'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCTDBdXzkB3z8Kpb0jiTXgCw',
#                         'channelTitle': 'Daniel Columbie',
#                         'description': 'Directed by: Daniel Columbie Written '
#                                        'by: Daniel Columbie & David Yuzuk '
#                                        'Music by: Akira Wing & Charetta '
#                                        'https://www.amidstthedevilswings.com '
#                                        '...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-11-25T02:10:45.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/KFzbZZCLnjQ/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/KFzbZZCLnjQ/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/KFzbZZCLnjQ/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Amidst the Devil&#39;s Wings - Official '
#                                  'Movie Trailer 2015'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 490},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/2mFoK4rcXJ4NAWyrnoLRqrl1hXU"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/lSwdJfZqU533Z1qYvX8W6CRhXL8"',
#             'id': {'kind': 'youtube#video', 'videoId': '-T7CM4di_0c'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCi8e0iOVk1fEOogdfu4YgfA',
#                         'channelTitle': 'Movieclips Trailers',
#                         'description': 'Subscribe to TRAILERS: '
#                                        'http://bit.ly/sxaw6h Subscribe to '
#                                        'COMING SOON: http://bit.ly/H2vZUn Like '
#                                        'us on FACEBOOK: http://bit.ly/1QyRMsE '
#                                        'Follow us on ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-08-26T14:04:28.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/-T7CM4di_0c/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/-T7CM4di_0c/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/-T7CM4di_0c/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Youth Official Trailer #1 (2015)  - Michael '
#                                  'Caine, Harvey Keitel Drama Movie HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/O7ZowBoNAMNgsqAow3VYLPVbRo8"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/wKqD3OfuY0oiAAN-N8eND6nGk2M"',
#             'id': {'kind': 'youtube#video', 'videoId': 'h6cVyoMH4QE'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCAVadSTSh382kte-fQHqMNw',
#                         'channelTitle': 'Legendary',
#                         'description': 'Krampus DVD and Blu-Ray - '
#                                        'http://amzn.to/2ehkhBw '
#                                        'http://www.krampusthefilm.com '
#                                        "Legendary Pictures' Krampus, a darkly "
#                                        'festive tale of a yuletide ghoul, ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-09-09T13:00:01.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/h6cVyoMH4QE/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/h6cVyoMH4QE/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/h6cVyoMH4QE/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Krampus - Official Trailer (HD)'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/o9LtKDjuIzRIp5NEl52rxQN3gZ4"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/aoCAClfmHM3MyMCNZI0Yp6xrx78"',
#             'id': {'kind': 'youtube#video', 'videoId': 'fvfjpeeDJjg'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCi8e0iOVk1fEOogdfu4YgfA',
#                         'channelTitle': 'Movieclips Trailers',
#                         'description': 'Subscribe to TRAILERS: '
#                                        'http://bit.ly/sxaw6h Subscribe to '
#                                        'COMING SOON: http://bit.ly/H2vZUn Like '
#                                        'us on FACEBOOK: http://goo.gl/dHs73 '
#                                        'Grace Of Monaco ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2014-03-06T14:38:13.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/fvfjpeeDJjg/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/fvfjpeeDJjg/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/fvfjpeeDJjg/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Grace Of Monaco Official UK Trailer #1 '
#                                  '(2013) - Nicole Kidman Movie HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 99878},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/meiGo0YCEApBCEcBiBtFsXOWYm4"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/P1AazckcWwzAicBBZzJfF5RC2AM"',
#             'id': {'kind': 'youtube#video', 'videoId': 'uU_ZvIup-3Y'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCLyYEq4ODlw3OD9qhGqwimw',
#                         'channelTitle': 'Movieclips Indie',
#                         'description': 'Subscribe to INDIE & FILM FESTIVALS: '
#                                        'http://bit.ly/1wbkfYg Subscribe to '
#                                        'TRAILERS: http://bit.ly/sxaw6h '
#                                        'Subscribe to COMING SOON: '
#                                        'http://bit.ly/H2vZUn Like ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-09-08T17:00:01.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/uU_ZvIup-3Y/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/uU_ZvIup-3Y/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/uU_ZvIup-3Y/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Shark Lake Official Trailer 1 (2015) - Dolph '
#                                  'Lundgren Thriller HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/Pt9vX0AyaNI6WOioMuqPTzfpXvU"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/qkpONSuvEEEkbNxOAXY9CN7Xq4w"',
#             'id': {'kind': 'youtube#playlist',
#                    'playlistId': 'PL0bpusoAyteaCzHWTcLoQ71XaOdqNH8EL'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCWjqI8alWlIdF0awiLyjl3A',
#                         'channelTitle': 'Bizarre - Topic',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2017-03-03T09:21:11.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/M13cpaMVUIw/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/M13cpaMVUIw/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/M13cpaMVUIw/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Popular Videos - Bizarre'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-397edf8432c0> in <module>
#      11
#      12     # add to key-value pair of movie and videoID to dictionary
# ---> 13     d3[movie] = response["items"][0]["id"]["videoId"]
#      14
#      15 # create another (same) for loop for m2, m3..etc
#
# KeyError: 'videoId'

# %%
# create dataframe from dictionary
df3 = pd.DataFrame.from_dict(list(d3.items()))
df3 = df3.rename(columns={0: "movie_trailer", 1: "video_id"})
df3
# Out:
#                                movie_trailer     video_id
# 0          The Ridiculous 6 Official Trailer  qUp7Qgimn38
# 1  Amidst the Devil's Wings Official Trailer  KFzbZZCLnjQ
# 2                     Youth Official Trailer  -T7CM4di_0c
# 3                   Krampus Official Trailer  h6cVyoMH4QE
# 4           Grace of Monaco Official Trailer  fvfjpeeDJjg
# 5                Shark Lake Official Trailer  uU_ZvIup-3Y

# %%
df3["video_title"] = ""
df3["channel_name"] = ""
df3["channel_id"] = ""
df3["comment_count"] = ""
df3["view_count"] = ""
df3["like_count"] = ""
df3["date_published"] = ""

# for loop to retrieve view count, comment count, like count for each video
for index, row in df3.iterrows():
    video = row["video_id"]
    index = index
    
    final_url = base_url + ("videos?part=snippet%2C+statistics&id={0}&key={1}").format(video, gkey)
    final_results = requests.get(final_url).json()
    vid_response = final_results["items"]
    
    for i in vid_response:
        t = i.get("snippet").get("title")
        c = i.get("snippet").get("channelTitle")
        d = i.get("snippet").get("channelId")
        m = i.get("snippet").get("publishedAt")

        comment_count = i.get("statistics").get("commentCount")
        view_count = i.get("statistics").get("viewCount")
        like_count = i.get("statistics").get("likeCount")
      
        df3.loc[index, "video_title"] = t
        df3.loc[index, "channel_name"] = c
        df3.loc[index, "channel_id"] = d
        df3.loc[index, "comment_count"] = comment_count
        df3.loc[index, "view_count"] = view_count
        df3.loc[index, "like_count"] = like_count
        df3.loc[index, "date_published"] = m
df3
# Out:
#                                movie_trailer     video_id  \
# 0          The Ridiculous 6 Official Trailer  qUp7Qgimn38
# 1  Amidst the Devil's Wings Official Trailer  KFzbZZCLnjQ
# 2                     Youth Official Trailer  -T7CM4di_0c
# 3                   Krampus Official Trailer  h6cVyoMH4QE
# 4           Grace of Monaco Official Trailer  fvfjpeeDJjg
# 5                Shark Lake Official Trailer  uU_ZvIup-3Y
#
#                                          video_title         channel_name  \
# 0  The Ridiculous 6 | Official Trailer [HD] | Net...              Netflix
# 1  Amidst the Devil's Wings - Official Movie Trai...      Daniel Columbie
# 2  Youth Official Trailer #1 (2015)  - Michael Ca...  Movieclips Trailers
# 3                    Krampus - Official Trailer (HD)            Legendary
# 4  Grace Of Monaco Official UK Trailer #1 (2013) ...  Movieclips Trailers
# 5  Shark Lake Official Trailer 1 (2015) - Dolph L...     Movieclips Indie
#
#                  channel_id comment_count view_count like_count  \
# 0  UCWOA1ZGywLbqmigxE4Qlvuw          3399    8763430      19433
# 1  UCTDBdXzkB3z8Kpb0jiTXgCw          None      39673        631
# 2  UCi8e0iOVk1fEOogdfu4YgfA           358    3102889       5746
# 3  UCAVadSTSh382kte-fQHqMNw         10331   18312209      65136
# 4  UCi8e0iOVk1fEOogdfu4YgfA           337    1381713       3695
# 5  UCLyYEq4ODlw3OD9qhGqwimw            87     524481        621
#
#              date_published
# 0  2015-10-27T15:25:07.000Z
# 1  2015-11-25T02:10:45.000Z
# 2  2015-08-26T14:04:28.000Z
# 3  2015-09-09T13:00:01.000Z
# 4  2014-03-06T14:38:13.000Z
# 5  2015-09-08T17:00:01.000Z

# %%
combined_df = combined_df.append(df3)
combined_df.count()
# Out:
# movie_trailer     30
# video_id          30
# video_title       30
# channel_name      30
# channel_id        30
# comment_count     29
# view_count        30
# like_count        30
# date_published    30
# dtype: int64

# %% [markdown]
# ## 4th list

# %%
# new dictionary
d4 = {}

# try to retrieve videoID for movies in m1 first 
for movie in m4: 
    search_url = base_url + ("search?part=snippet&maxResults=1&q={0}&key={1}").format(movie, gkey)
    
    response = requests.get(search_url).json()
    # check response
    pprint(response)
    
    # add to key-value pair of movie and videoID to dictionary
    d4[movie] = response["items"][0]["id"]["videoId"]

# create another (same) for loop for m2, m3..etc 
pprint(d4)
# Out:
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/LoicRT0oCHfEXIsReohFts6ouHM"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/EchJnhCuVUsG9lH6eM-ylQRJqsY"',
#             'id': {'kind': 'youtube#video', 'videoId': 'hOoIBOYqHyw'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCjmJDM5pRKbUlVIzDYYWb6g',
#                         'channelTitle': 'Warner Bros. Pictures',
#                         'description': 'The 33 - in theaters November 13th. '
#                                        'http://the33movie.com '
#                                        'https://www.facebook.com/the33movie '
#                                        '--- From Alcon Entertainment and '
#                                        'Phoenix Pictures comes the ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-07-29T14:00:58.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/hOoIBOYqHyw/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/hOoIBOYqHyw/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/hOoIBOYqHyw/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'The 33 - Official Trailer [HD]'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/JUUTu1SdcK7vyfEQTA80PAeWSao"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/_HXjrUkfp3O6KB4Uz8_qgRmLp5A"',
#             'id': {'kind': 'youtube#video', 'videoId': '-TSX_0rwPNc'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCi8e0iOVk1fEOogdfu4YgfA',
#                         'channelTitle': 'Movieclips Trailers',
#                         'description': 'Subscribe to TRAILERS: '
#                                        'http://bit.ly/sxaw6h Subscribe to '
#                                        'COMING SOON: http://bit.ly/H2vZUn Like '
#                                        'us on FACEBOOK: http://bit.ly/1QyRMsE '
#                                        'Follow us on ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-08-26T19:33:48.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/-TSX_0rwPNc/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/-TSX_0rwPNc/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/-TSX_0rwPNc/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Love the Coopers Official Trailer #1 (2015) '
#                                  '- Olivia Wilde, Amanda Seyfried Movie HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/zFMRz9YpmcGtn3W-GwYf8P-kYaU"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/478VOQHMg5qDQqG8YHmm_LVkOo0"',
#             'id': {'kind': 'youtube#video', 'videoId': 'ZdhCG68kMIo'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCQLBOKpgXrSj3nPU-YC3K9Q',
#                         'channelTitle': 'Universal Pictures UK',
#                         'description': 'By the Sea Official Trailer - In '
#                                        'cinemas December 11, 2015 Written, '
#                                        'directed and produced by Academy '
#                                        'Award® winner Angelina Jolie Pitt, By '
#                                        'the Sea serves as ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-10-30T16:34:41.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/ZdhCG68kMIo/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/ZdhCG68kMIo/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/ZdhCG68kMIo/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'By the Sea - Official Trailer (Universal '
#                                  'Pictures)'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/eeiyafyHWsb_9sx7h81kTYTFW8w"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/yEq2T3rDopXsXNxmNYDhH4IMnDA"',
#             'id': {'kind': 'youtube#video', 'videoId': 'udOir1ucj38'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCLyYEq4ODlw3OD9qhGqwimw',
#                         'channelTitle': 'Movieclips Indie',
#                         'description': 'Subscribe to INDIE & FILM FESTIVALS: '
#                                        'http://bit.ly/1wbkfYg Subscribe to '
#                                        'TRAILERS: http://bit.ly/sxaw6h '
#                                        'Subscribe to COMING SOON: '
#                                        'http://bit.ly/H2vZUn Like ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-09-03T17:30:37.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/udOir1ucj38/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/udOir1ucj38/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/udOir1ucj38/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'My All American Official Trailer 1 (2015) - '
#                                  'Aaron Eckhart, Finn Wittrock Movie HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/pfHx8hsKV1VQUsrMpYwwFPuBVaQ"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/OqbKxhsuZN05ru3DseTwALu2jdI"',
#             'id': {'kind': 'youtube#video', 'videoId': 'BvJDL8v8lTk'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCJ6nMHaJPZvsJ-HmUmj1SeA',
#                         'channelTitle': 'Lionsgate Movies',
#                         'description': 'When their attempt to rob a casino '
#                                        'owned by the feared gangster Pope '
#                                        '(Robert De Niro) goes awry and a '
#                                        'shootout ensues, Vaughn (Jeffrey Dean '
#                                        'Morgan) and ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-09-19T17:00:05.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/BvJDL8v8lTk/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/BvJDL8v8lTk/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/BvJDL8v8lTk/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'HEIST (2015 Movie - Robert De Niro, Jeffrey '
#                                  'Dean Morgan) – Official Trailer'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/Ew2GbHp8nb-eG7xYZ9Di0WkBoNI"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/7Dzxp56_bJG6C-QYTsKC3pDQFqI"',
#             'id': {'kind': 'youtube#video', 'videoId': 'RNkbx9pZUKI'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCVXO1_7BI7cCJFdIqXKGhuA',
#                         'channelTitle': 'FilmIsNow Movie Trailers '
#                                         'International',
#                         'description': 'Subscribe to our channel: '
#                                        'http://goo.gl/Etb1I3 Watch the trailer '
#                                        'for the drama 10 Days in a Madhouse '
#                                        'Starring Caroline Barry, Christopher '
#                                        'Lambert, Kelly Le ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-11-10T16:43:47.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/RNkbx9pZUKI/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/RNkbx9pZUKI/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/RNkbx9pZUKI/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': '10 DAYS IN A MADHOUSE Official Trailer '
#                                  '(2015) - Caroline Barry [HD]'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 602518},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/PpYtzJRW8xGuwfHvdQYgYO3KtSk"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/TdqYOb8NbSKUUYzDHeBYeFm7e2I"',
#             'id': {'kind': 'youtube#video', 'videoId': 'Jx9jJ9idKDo'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'U
',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/X3pfHyKRAfYT1g8SWyq2eFhTmr0"',
#             'id': {'kind': 'youtube#video', 'videoId': 'w01G6jwqcUc'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCjiGHzoTdJv10m3bwKWf6ew',
#                         'channelTitle': 'The Movie Times',
#                         'description': "Don't wait in line! Buy movie tickets "
#                                        'in over 60 countries at '
#                                        'http://movie-times.net. Plus '
#                                        'interviews with the people who make '
#                                        'the movies you love, international ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-10-30T14:55:32.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/w01G6jwqcUc/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/w01G6jwqcUc/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/w01G6jwqcUc/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'DANCIN&#39; IT&#39;S ON: Official Trailer'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/vyjzzJ08bm0k6CVyArNaYxdPWpI"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/6I1AbZJ1WKO_MVza5vlcMxHT-Yk"',
#             'id': {'kind': 'youtube#video', 'videoId': 'eNXH63gCOG8'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCz97F7dMxBNOfGYu3rx8aCw',
#                         'channelTitle': 'Sony Pictures Entertainment',
#                         'description': 'This Halloween, watch the newest '
#                                        'horror battle in Freaks of Nature. Get '
#                                        'tickets now! '
#                                        'http://sonypictur.es/FreaksOfNatureTix '
#                                        'Follow Us: ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-10-16T17:00:26.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/eNXH63gCOG8/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/eNXH63gCOG8/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/eNXH63gCOG8/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Freaks of Nature - Official Red Band Trailer '
#                                  '(In Theaters 10/30)'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'10 Days in a Madhouse Official Trailer': 'RNkbx9pZUKI',
#  'Brooklyn Official Trailer': '15syDwC000k',
#  'Burnt Official Trailer': 'QsyzkkI_g14',
#  'By the Sea Official Trailer': 'ZdhCG68kMIo',
#  "Dancin' It's On Official Trailer": 'w01G6jwqcUc',
#  'Freaks of Nature Official Trailer': 'eNXH63gCOG8',
#  'Heist Official Trailer': 'BvJDL8v8lTk',
#  'Love the Coopers Official Trailer': '-TSX_0rwPNc',
#  'My All-American Official Trailer': 'udOir1ucj38',
#  'Our Brand is Crisis Official Trailer': 'BLZo_ILZhfk',
#  'Perfect Cowboy Official Trailer': 'PhFfs_aDD7U',
#  'Regression Official Trailer': '-pBwIsVGaL4',
#  'Scouts Guide to the Zombie Apocalypse Official Trailer': 'ZOhSbNJ7MqI',
#  'Spectre Official Trailer': 'ujmoYyEyDP8',
#  'Spotlight Official Trailer': '56jw6tasomc',
#  'The 33 Official Trailer': 'hOoIBOYqHyw',
#  'The Final Girls Official Trailer': 'zreNh78kTjg',
#  'The Little Ponderosa Zoo Official Trailer': 'Jx9jJ9idKDo',
#  'The Night Visitor Official Trailer': 'ptewQOmP1Qk',
#  'The Peanuts Movie Official Trailer': 'zQpUQPrAfQM'}

# %%
# create dataframe from dictionary
df4 = pd.DataFrame.from_dict(list(d4.items()))
df4 = df4.rename(columns={0: "movie_trailer", 1: "video_id"})
df4
# Out:
#                                         movie_trailer     video_id
# 0                             The 33 Official Trailer  hOoIBOYqHyw
# 1                   Love the Coopers Official Trailer  -TSX_0rwPNc
# 2                         By the Sea Official Trailer  ZdhCG68kMIo
# 3                    My All-American Official Trailer  udOir1ucj38
# 4                              Heist Official Trailer  BvJDL8v8lTk
# 5              10 Days in a Madhouse Official Trailer  RNkbx9pZUKI
# 6           The Little Ponderosa Zoo Official Trailer  Jx9jJ9idKDo
# 7                     Perfect Cowboy Official Trailer  PhFfs_aDD7U
# 12                      BROOKLYN: Official HD Trailer
# 13  The Final Girls Official Trailer 1 (2015) - Ni...
# 14  Burnt Official Teaser Trailer #1 (2015) - Brad...
# 15        Our Brand Is Crisis - Official Trailer [HD]
# 16  Regression Official Trailer #1 (2015) - Emma W...
# 17  Scouts Guide to the Zombie Apocalypse Official...
# 18                  DANCIN' IT'S ON: Official Trailer
# 19  Freaks of Nature - Official Red Band Trailer (...
#
#                               channel_name                channel_id  \
# 0                    Warner Bros. Pictures  UCjmJDM5pRKbUlVIzDYYWb6g
# 1                      Movieclips Trailers  UCi8e0iOVk1fEOogdfu4YgfA
# 2                    Universal Pictures UK  UCQLBOKpgXrSj3nPU-YC3K9Q
# 3                         Movieclips Indie  UCLyYEq4ODlw3OD9qhGqwimw
# 4                         Lionsgate Movies  UCJ6nMHaJPZvsJ-HmUmj1SeA
# 5   FilmIsNow Movie Trailers International  UCVXO1_7BI7cCJFdIqXKGhuA
# 6                 Mill Creek Entertainment  UCmP5P_EAmIjcueFonnpaKHw
# 7                  Breaking Glass Pictures  UCXbxUFqpifDSRdvxhpA_TSA
# 8                                Mak Miler  UCTIWTUPVXJ6FbsydT9i_hxA
# 9              Sony Pictures Entertainment  UCz97F7dMxBNOfGYu3rx8aCw
# 10                     Movieclips Trailers  UCi8e0iOVk1fEOogdfu4YgfA
# 11                     Movieclips Trailers  UCi8e0iOVk1fEOogdfu4YgfA
# 12                          FoxSearchlight  UCor9rW6PgxSQ9vUPWQdnaYQ
# 13                        Movieclips Indie  UCLyYEq4ODlw3OD9qhGqwimw
# 14                     Movieclips Trailers  UCi8e0iOVk1fEOogdfu4YgfA
# 15                   Warner Bros. Pictures  UCjmJDM5pRKbUlVIzDYYWb6g
# 16                     Movieclips Trailers  UCi8e0iOVk1fEOogdfu4YgfA
# 17                     Movieclips Trailers  UCi8e0iOVk1fEOogdfu4YgfA
# 18                         The Movie Times  UCjiGHzoTdJv10m3bwKWf6ew
# 19             Sony Pictures Entertainment  UCz97F7dMxBNOfGYu3rx8aCw
#
#    comment_count view_count like_count            date_published
# 0           1653    6530633      16256  2015-07-29T14:00:58.000Z
# 1            650    5562051      18971  2015-08-26T19:33:48.000Z
# 2             88     322724        781  2015-10-30T16:34:41.000Z
# 3            298    1182480       6553  2015-09-03T17:30:37.000Z
# 4            452    2692235       2596  2015-09-19T17:00:05.000Z
# 5              5      41035        103  2015-11-10T16:43:47.000Z
# 6              1      12240         26  2015-10-06T14:32:43.000Z
# 7              1      11713         65  2015-11-12T20:22:14.000Z
# 8              0       7244          8  2013-09-08T12:18:58.000Z
# 9            470    4414257       5257  2015-07-22T07:01:02.000Z
# 10           667    1937080       6357  2015-07-29T16:22:41.000Z
# 11          1297    3321686      13590  2015-06-18T18:27:34.000Z
# 12           901    4617511      11882  2015-07-09T15:27:47.000Z
# 13          1332    4562366      26322  2015-08-21T17:15:03.000Z
# 14           892    3796375      11103  2015-08-14T15:08:25.000Z
# 15           431    4471153       4348  2015-09-08T17:00:04.000Z
# 16          2123    9866980      28016  2015-06-10T13:37:38.000Z
# 17           958    3760859      19823  2015-08-25T13:17:01.000Z
# 18            45      32638         74  2015-10-30T14:55:32.000Z
# 19           125     528677       1684  2015-10-16T17:00:26.000Z

# %%
combined_df = combined_df.append(df4)
combined_df.count()
# Out:
# movie_trailer     50
# video_id          50
# video_title       50
# channel_name      50
# channel_id        50
# comment_count     49
# view_count        50
# like_count        50
# date_published    50
# dtype: int64

# %% [markdown]
# ## 5th request

# %%
# new dictionary
d5 = {}

# try to retrieve videoID for movies in m1 first 
for movie in m5: 
    search_url = base_url + ("search?part=snippet&maxResults=1&q={0}&key={1}").format(movie, gkey)
    
    response = requests.get(search_url).json()
    # check response
    pprint(response)
    
    # add to key-value pair of movie and videoID to dictionary
    d5[movie] = response["items"][0]["id"]["videoId"]

pprint(d5)
# Out:
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/cWklX2rzyYwReqKF-hcFLcRas1U"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/_hZTt2O1v0AyivCqrv1xx1xmlJc"',
#             'id': {'kind': 'youtube#video', 'videoId': 'r6nJUCXjVlE'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCbJbnodRKQtOz4pzVHRN1qg',
#                         'channelTitle': 'Running Forever - Trailer',
#                         'description': 'After being estranged since her '
#                                        "mother's death in the 9/11 attacks, "
#                                        'both daughter and father must work '
#                                        'together to re-establish their '
#                                        'relationship. When the ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2017-10-03T04:00:59.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/r6nJUCXjVlE/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/r6nJUCXjVlE/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/r6nJUCXjVlE/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Running Forever - Trailer'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/0OySbxgZzzQOnIIzMjLzc8mDuo8"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/YobqObuOLT63rnCCnY3RjoR6xgA"',
#             'id': {'kind': 'youtube#video', 'videoId': 'FWS40n0MUzs'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCzNWVDZQ55bjq8uILZ7_wyQ',
#                         'channelTitle': 'FRESH Movie Trailers',
#                         'description': 'An unforgettable, disturbing tapestry '
#                                        'of terror, by 6 promising directors ! '
#                                        '☆ Join-us on Facebook ➨ '
#                                        'http://facebook.com/HorrorScifiMovies '
#                                        '☆ The Best HORROR ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-10-03T01:00:00.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/FWS40n0MUzs/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/FWS40n0MUzs/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/FWS40n0MUzs/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'THE HORROR NETWORK Movie Trailer (Horror - '
#                                  '2015'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/UuXOj-9jYAco8KQ6BlYxerRwpeo"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/XkNWzYPFeOyNhcL2nqmAMMlgEhQ"',
#             'id': {'kind': 'youtube#video', 'videoId': 'T_Xev0-h5iE'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCi8e0iOVk1fEOogdfu4YgfA',
#                         'channelTitle': 'Movieclips Trailers',
#                         'description': 'Subscribe to TRAILERS: '
#                                        'http://bit.ly/sxaw6h Subscribe to '
#                                        'COMING SOON: http://bit.ly/H2vZUn Like '
#                                        'us on FACEBOOK: http://bit.ly/1QyRMsE '
#                                        'Follow us on ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-08-28T18:14:33.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/T_Xev0-h5iE/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/T_Xev0-h5iE/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/T_Xev0-h5iE/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Rock the Kasbah Official Trailer #2 (2015) - '
#                                  'Kate Hudson, Bill Murray Comedy HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 104713},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/jVMINoiMxJGA7Rtq9RKyQxhaibs"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/E9ldt00Zwej8QRsZ5EG0-tt4-dU"',
#             'id': {'kind': 'youtube#video', 'videoId': 'xsuG2JUgs_8'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCJ6nMHaJPZvsJ-HmUmj1SeA',
#                         'channelTitle': 'Lionsgate Movies',
#                         'description': 'Live Forever. Hunt Forever. The Last '
#                                        'Witch Hunter. Starring Vin Diesel, '
#                                        'Elijah Wood, Rose Leslie and Michael '
#                                        'Caine. #LastWitchHunter #AxeAndCross '
#                                        '...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-08-06T15:59:45.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/xsuG2JUgs_8/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/xsuG2JUgs_8/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/xsuG2JUgs_8/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'The Last Witch Hunter (2015) Official '
#                                  'Trailer – &quot;Live Forever&quot; - Vin '
#                                  'Diesel'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1000000},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/gXTpBkOQ2UJ9HTp76FSSsWmj8Vc"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/w1ggfrjFg3TgidAtDGjPFmXSfb4"',
#             'id': {'kind': 'youtube#video', 'videoId': '0ZbwtHi-KSE'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCi8e0iOVk1fEOogdfu4YgfA',
#                         'channelTitle': 'Movieclips Trailers',
#                         'description': 'Subscribe to TRAILERS: '
#                                        'http://bit.ly/sxaw6h Subscribe to '
#                                        'COMING SOON: http://bit.ly/H2vZUn Like '
#                                        'us on FACEBOOK: http://bit.ly/1QyRMsE '
#                                        'Follow us on ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-10-05T18:04:57.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/0ZbwtHi-KSE/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/0ZbwtHi-KSE/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/0ZbwtHi-KSE/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Bone Tomahawk Official Trailer #1 (2015) - '
#                                  'Kurt Russell, Patrick Wilson Movie HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 620573},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/oZcvDjCGfKE7MtYP9BU36akgZWM"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/sHGw7GkfOFMfc2A0MFl2OvJ7TjY"',
#             'id': {'kind': 'youtube#video', 'videoId': 'pifhszsZKg4'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCq0OueAsdxH6b8nyAspwViw',
#                         'channelTitle': 'Universal Pictures',
#                         'description': 'Jem And The Holograms - Official '
#                                        'Trailer (HD) In Theaters October 23 '
#                                        'http://www.jemthemovie.com/ As a '
#                                        'small-town girl catapults from '
#                                        'underground video ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-05-13T16:18:40.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/pifhszsZKg4/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/pifhszsZKg4/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/pifhszsZKg4/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Jem And The Holograms - Official Trailer '
#                                  '(HD)'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 360020},
#  'regionCode': 'US'}
# {'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/1nn1uNG8w_hSE9SHyEzq8MGE69A"',
#  'items': [{'etag': '"nlUZBA6NbTS7q9G8D1GljyfTIWI/XVR4eqO9dOAgj5ebE-g5fvOw_VE"',
#             'id': {'kind': 'youtube#video', 'videoId': '056FI2Pq9RY'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCi8e0iOVk1fEOogdfu4YgfA',
#                         'channelTitle': 'Movieclips Trailers',
#                         'description': 'Subscribe to TRAILERS: '
#                                        'http://bit.ly/sxaw6h Subscribe to '
#                                        'COMING SOON: http://bit.ly/H2vZUn Like '
#                                        'us on FACEBOOK: http://goo.gl/dHs73 '
#                                        'Follow us on ...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2015-06-03T18:51:16.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/056FI2Pq9RY/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/056FI2Pq9RY/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/056FI2Pq9RY/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Suffragette Official Trailer #1 (2015) - '
#                                  'Carey Mulligan, Meryl Streep Drama HD'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 146891},
#  'regionCode': 'US'}
# {'error': {'code': 403,
#            'errors': [{'domain': 'youtube.quota',
#                        'message': 'The request cannot be completed because you '
#                                   'have exceeded your <a '
#                                   'href="/youtube/v3/getting-started#quota">quota</a>.',
#                        'reason': 'quotaExceeded'}],
#            'message': 'The request cannot be completed because you have '
#                       'exceeded your <a '
#                       'href="/youtube/v3/getting-started#quota">quota</a>.'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-cbd0b171bea5> in <module>
#      11
#      12     # add to key-value pair of movie and videoID to dictionary
# ---> 13     d5[movie] = response["items"][0]["id"]["videoId"]
#      14
#      15 pprint(d5)
#
# KeyError: 'items'

# %%
# create dataframe from dictionary
df5 = pd.DataFrame.from_dict(list(d5.items()))
df5 = df5.rename(columns={0: "movie_trailer", 1: "video_id"})
df5
# Out:
#                             movie_trailer     video_id
# 0        Running Forever Official Trailer  r6nJUCXjVlE
# 1     The Horror Network Official Trailer  FWS40n0MUzs
# 2        Rock the Kasbah Official Trailer  T_Xev0-h5iE
# 3  The Last Witch Hunter Official Trailer  xsuG2JUgs_8
# 4          Bone Tomahawk Official Trailer  0ZbwtHi-KSE
# 5  Jem and the Holograms Official Trailer  pifhszsZKg4
# 6            Suffragette Official Trailer  056FI2Pq9RY

# %%
df5["video_title"] = ""
df5["channel_name"] = ""
df5["channel_id"] = ""
df5["comment_count"] = ""
df5["view_count"] = ""
df5["like_count"] = ""
df5["date_published"] = ""

# for loop to retrieve view count, comment count, like count for each video
for index, row in df5.iterrows():
    video = row["video_id"]
    index = index
    
    final_url = base_url + ("videos?part=snippet%2C+statistics&id={0}&key={1}").format(video, gkey)
    final_results = requests.get(final_url).json()
    vid_response = final_results["items"]
    
    for i in vid_response:
        t = i.get("snippet").get("title")
        c = i.get("snippet").get("channelTitle")
        d = i.get("snippet").get("channelId")
        m = i.get("snippet").get("publishedAt")

        comment_count = i.get("statistics").get("commentCount")
        view_count = i.get("statistics").get("viewCount")
        like_count = i.get("statistics").get("likeCount")
      
        df5.loc[index, "video_title"] = t
        df5.loc[index, "channel_name"] = c
        df5.loc[index, "channel_id"] = d
        df5.loc[index, "comment_count"] = comment_count
        df5.loc[index, "view_count"] = view_count
        df5.loc[index, "like_count"] = like_count
        df5.loc[index, "date_published"] = m
df5

# %%
combined_df = combined_df.append(df5)
combined_df.count()
# Out:
# movie_trailer     57
# video_id          57
# video_title       57
# channel_name      57
# channel_id        57
# comment_count     55
# view_count        57
# like_count        56
# date_published    57
# dtype: int64

# %%
# new dictionary
d6 = {}

# try to retrieve videoID for movies in m1 first 
for movie in m6: 
    search_url = base_url + ("search?part=snippet&maxResults=1&q={0}&key={1}").format(movie, gkey)
    
    response = requests.get(search_url).json()
    # check response
    pprint(response)
    
    # add to key-value pair of movie and videoID to dictionary
    d6[movie] = response["items"][0]["id"]["videoId"]

# create another (same) for loop for m2, m3..etc 
pprint(d6)

# %%
# create dataframe from dictionary
df6 = pd.DataFrame.from_dict(list(d6.items()))
df6 = df6.rename(columns={0: "movie_trailer", 1: "video_id"})
df6

# %%
df6["video_title"] = ""
df6["channel_name"] = ""
df6["channel_id"] = ""
df6["comment_count"] = ""
df6["view_count"] = ""
df6["like_count"] = ""
df6["date_published"] = ""

# for loop to retrieve view count, comment count, like count for each video
for index, row in df6.iterrows():
    video = row["video_id"]
    index = index
    
    final_url = base_url + ("videos?part=snippet%2C+statistics&id={0}&key={1}").format(video, gkey)
    final_results = requests.get(final_url).json()
    vid_response = final_results["items"]
    
    for i in vid_response:
        t = i.get("snippet").get("title")
        c = i.get("snippet").get("channelTitle")
        d = i.get("snippet").get("channelId")
        m = i.get("snippet").get("publishedAt")

        comment_count = i.get("statistics").get("commentCount")
        view_count = i.get("statistics").get("viewCount")
        like_count = i.get("statistics").get("likeCount")
      
        df6.loc[index, "video_title"] = t
        df6.loc[index, "channel_name"] = c
        df6.loc[index, "channel_id"] = d
        df6.loc[index, "comment_count"] = comment_count
        df6.loc[index, "view_count"] = view_count
        df6.loc[index, "like_count"] = like_count
        df6.loc[index, "date_published"] = m
df6

# %%
combined_df = combined_df.append(df6)
combined_df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-992df96c0a5a> in <module>
# ----> 1 combined_df = combined_df.append(df6)
#       2 combined_df.count()
#
# NameError: name 'df6' is not defined

# %% [markdown]
# ## 7th request

# %%
# new dictionary
d7 = {}

# try to retrieve videoID for movies in m1 first 
for movie in m7: 
    search_url = base_url + ("search?part=snippet&maxResults=1&q={0}&key={1}").format(movie, gkey)
    
    response = requests.get(search_url).json()
    # check response
    pprint(response)
    
    # add to key-value pair of movie and videoID to dictionary
    d7[movie] = response["items"][0]["id"]["videoId"]

pprint(d7)

# %%
# create dataframe from dictionary
df7 = pd.DataFrame.from_dict(list(d7.items()))
df7 = df7.rename(columns={0: "movie_trailer", 1: "video_id"})
df7

# %%
df7["video_title"] = ""
df7["channel_name"] = ""
df7["channel_id"] = ""
df7["comment_count"] = ""
df7["view_count"] = ""
df7["like_count"] = ""
df7["date_published"] = ""

# for loop to retrieve view count, comment count, like count for each video
for index, row in df7.iterrows():
    video = row["video_id"]
    index = index
    
    final_url = base_url + ("videos?part=snippet%2C+statistics&id={0}&key={1}").format(video, gkey)
    final_results = requests.get(final_url).json()
    vid_response = final_results["items"]
    
    for i in vid_response:
        t = i.get("snippet").get("title")
        c = i.get("snippet").get("channelTitle")
        d = i.get("snippet").get("channelId")
        m = i.get("snippet").get("publishedAt")

        comment_count = i.get("statistics").get("commentCount")
        view_count = i.get("statistics").get("viewCount")
        like_count = i.get("statistics").get("likeCount")
      
        df7.loc[index, "video_title"] = t
        df7.loc[index, "channel_name"] = c
        df7.loc[index, "channel_id"] = d
        df7.loc[index, "comment_count"] = comment_count
        df7.loc[index, "view_count"] = view_count
        df7.loc[index, "like_count"] = like_count
        df7.loc[index, "date_published"] = m
df7

# %%
combined_df = combined_df.append(df7)
combined_df.count()

# %% [markdown]
# ## 8th request

# %%
# new dictionary
d8 = {}

# try to retrieve videoID for movies in m1 first 
for movie in m8: 
    search_url = base_url + ("search?part=snippet&maxResults=1&q={0}&key={1}").format(movie, gkey)
    
    response = requests.get(search_url).json()
    # check response
    pprint(response)
    
    # add to key-value pair of movie and videoID to dictionary
    d8[movie] = response["items"][0]["id"]["videoId"]

pprint(d8)

# %%
# create dataframe from dictionary
df8 = pd.DataFrame.from_dict(list(d8.items()))
df8 = df8.rename(columns={0: "movie_trailer", 1: "video_id"})
df8

# %%
df8["video_title"] = ""
df8["channel_name"] = ""
df8["channel_id"] = ""
df8["comment_count"] = ""
df8["view_count"] = ""
df8["like_count"] = ""
df8["date_published"] = ""

# for loop to retrieve view count, comment count, like count for each video
for index, row in df8.iterrows():
    video = row["video_id"]
    index = index
    
    final_url = base_url + ("videos?part=snippet%2C+statistics&id={0}&key={1}").format(video, gkey)
    final_results = requests.get(final_url).json()
    vid_response = final_results["items"]
    
    for i in vid_response:
        t = i.get("snippet").get("title")
        c = i.get("snippet").get("channelTitle")
        d = i.get("snippet").get("channelId")
        m = i.get("snippet").get("publishedAt")

        comment_count = i.get("statistics").get("commentCount")
        view_count = i.get("statistics").get("viewCount")
        like_count = i.get("statistics").get("likeCount")
      
        df8.loc[index, "video_title"] = t
        df8.loc[index, "channel_name"] = c
        df8.loc[index, "channel_id"] = d
        df8.loc[index, "comment_count"] = comment_count
        df8.loc[index, "view_count"] = view_count
        df8.loc[index, "like_count"] = like_count
        df8.loc[index, "date_published"] = m
df8

# %%
combined_df = combined_df.append(df8)
combined_df.count()

# %% [markdown]
# ## 9th request

# %%
# new dictionary
d9 = {}

# try to retrieve videoID for movies in m1 first 
for movie in m9: 
    search_url = base_url + ("search?part=snippet&maxResults=1&q={0}&key={1}").format(movie, gkey)
    
    response = requests.get(search_url).json()
    # check response
    pprint(response)
    
    # add to key-value pair of movie and videoID to dictionary
    d9[movie] = response["items"][0]["id"]["videoId"]

pprint(d9)

# %%
# create dataframe from dictionary
df9 = pd.DataFrame.from_dict(list(d9.items()))
df9 = df9.rename(columns={0: "movie_trailer", 1: "video_id"})
df9

# %%
df9["video_title"] = ""
df9["channel_name"] = ""
df9["channel_id"] = ""
df9["comment_count"] = ""
df9["view_count"] = ""
df9["like_count"] = ""
df9["date_published"] = ""

# for loop to retrieve view count, comment count, like count for each video
for index, row in df9.iterrows():
    video = row["video_id"]
    index = index
    
    final_url = base_url + ("videos?part=snippet%2C+statistics&id={0}&key={1}").format(video, gkey)
    final_results = requests.get(final_url).json()
    vid_response = final_results["items"]
    
    for i in vid_response:
        t = i.get("snippet").get("title")
        c = i.get("snippet").get("channelTitle")
        d = i.get("snippet").get("channelId")
        m = i.get("snippet").get("publishedAt")

        comment_count = i.get("statistics").get("commentCount")
        view_count = i.get("statistics").get("viewCount")
        like_count = i.get("statistics").get("likeCount")
      
        df9.loc[index, "video_title"] = t
        df9.loc[index, "channel_name"] = c
        df9.loc[index, "channel_id"] = d
        df9.loc[index, "comment_count"] = comment_count
        df9.loc[index, "view_count"] = view_count
        df9.loc[index, "like_count"] = like_count
        df9.loc[index, "date_published"] = m
df9

# %%
combined_df = combined_df.append(df9)
combined_df.count()

# %% [markdown]
# ## 10th request

# %%
# new dictionary
d10 = {}

# try to retrieve videoID for movies in m1 first 
for movie in m10: 
    search_url = base_url + ("search?part=snippet&maxResults=1&q={0}&key={1}").format(movie, gkey)
    
    response = requests.get(search_url).json()
    # check response
    pprint(response)
    
    # add to key-value pair of movie and videoID to dictionary
    d10[movie] = response["items"][0]["id"]["videoId"]

pprint(d10)

# %%
# create dataframe from dictionary
df10 = pd.DataFrame.from_dict(list(d10.items()))
df10 = df10.rename(columns={0: "movie_trailer", 1: "video_id"})
df10

# %%
df10["video_title"] = ""
df10["channel_name"] = ""
df10["channel_id"] = ""
df10["comment_count"] = ""
df10["view_count"] = ""
df10["like_count"] = ""
df10["date_published"] = ""

# for loop to retrieve view count, comment count, like count for each video
for index, row in df10.iterrows():
    video = row["video_id"]
    index = index
    
    final_url = base_url + ("videos?part=snippet%2C+statistics&id={0}&key={1}").format(video, gkey)
    final_results = requests.get(final_url).json()
    vid_response = final_results["items"]
    
    for i in vid_response:
        t = i.get("snippet").get("title")
        c = i.get("snippet").get("channelTitle")
        d = i.get("snippet").get("channelId")
        m = i.get("snippet").get("publishedAt")

        comment_count = i.get("statistics").get("commentCount")
        view_count = i.get("statistics").get("viewCount")
        like_count = i.get("statistics").get("likeCount")
      
        df10.loc[index, "video_title"] = t
        df10.loc[index, "channel_name"] = c
        df10.loc[index, "channel_id"] = d
        df10.loc[index, "comment_count"] = comment_count
        df10.loc[index, "view_count"] = view_count
        df10.loc[index, "like_count"] = like_count
        df10.loc[index, "date_published"] = m
df10

# %%
combined_df = combined_df.append(df10)
combined_df.count()

# %% [markdown]
# ## 11th request

# %%
# new dictionary
d11 = {}

# try to retrieve videoID for movies in m1 first 
for movie in m11: 
    search_url = base_url + ("search?part=snippet&maxResults=1&q={0}&key={1}").format(movie, gkey)
    
    response = requests.get(search_url).json()
    # check response
    pprint(response)
    
    # add to key-value pair of movie and videoID to dictionary
    d11[movie] = response["items"][0]["id"]["videoId"]

pprint(d11)

# %%
# create dataframe from dictionary
df11 = pd.DataFrame.from_dict(list(d11.items()))
df11 = df11.rename(columns={0: "movie_trailer", 1: "video_id"})
df11

# %%
df11["video_title"] = ""
df11["channel_name"] = ""
df11["channel_id"] = ""
df11["comment_count"] = ""
df11["view_count"] = ""
df11["like_count"] = ""
df11["date_published"] = ""

# for loop to retrieve view count, comment count, like count for each video
for index, row in df11.iterrows():
    video = row["video_id"]
    index = index
    
    final_url = base_url + ("videos?part=snippet%2C+statistics&id={0}&key={1}").format(video, gkey)
    final_results = requests.get(final_url).json()
    vid_response = final_results["items"]
    
    for i in vid_response:
        t = i.get("snippet").get("title")
        c = i.get("snippet").get("channelTitle")
        d = i.get("snippet").get("channelId")
        m = i.get("snippet").get("publishedAt")

        comment_count = i.get("statistics").get("commentCount")
        view_count = i.get("statistics").get("viewCount")
        like_count = i.get("statistics").get("likeCount")
      
        df11.loc[index, "video_title"] = t
        df11.loc[index, "channel_name"] = c
        df11.loc[index, "channel_id"] = d
        df11.loc[index, "comment_count"] = comment_count
        df11.loc[index, "view_count"] = view_count
        df11.loc[index, "like_count"] = like_count
        df11.loc[index, "date_published"] = m
df11

# %%
combined_df = combined_df.append(df11)
combined_df.count()

# %%
combined_df = combined_df.replace({None: 0})
combined_df.count()

# %%
combined_df["Year"] = 2016
combined_df.tail()

# %%
combined_df.to_csv('../Data/youtube_data/yt_2015.csv',index=False)
